# %% [markdown]
# ### Scenario:
# You have joined a real estate company as a Data Analyst. The company has provided you with historical
# house sales data. Your task is to answer business questions using Pandas.
#
# 1. Single Column Selection
#
# Q1. The sales manager wants to see only the selling prices of all houses. Display the column containing
# house prices.
#
# Q2. Display only the neighborhood information for all properties.
#
# Q3. Show the overall quality ratings of all houses.
#
# Q4. Display only the year in which each house was built.
#
# Q5. Show the garage capacity of all houses.

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df['Neighborhood']
# Out:
# 0       CollgCr
# 1       Veenker
# 2       CollgCr
# 3       Crawfor
# 4       NoRidge
#          ...
# 1455    Gilbert
# 1456     NWAmes
# 1457    Crawfor
# 1458      NAmes
# 1459    Edwards
# Name: Neighborhood, Length: 1460, dtype: str

# %%
df['OverallQual']
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
df['YearBuilt']
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %% [markdown]
# ### 2. Multiple Column Selection
#
# Q6. The marketing team wants to create a brochure containing the neighborhood, sale price, and living
# area of each property.
#
# Q7. Display the columns:
# Neighborhood
# OverallQual
# SalePrice
#
# Q8. Create a report containing:
# YearBuilt
# GarageCars
# SalePrice
#
# Q9. Show:
# HouseStyle
# BldgType
# SaleCondition
#
# Q10. Display:
# LotArea
# GrLivArea
# SalePrice

# %%
df[['Neighborhood','SalePrice','GrLivArea']]
# Out:
#      Neighborhood  SalePrice  GrLivArea
# 0         CollgCr     208500       1710
# 1         Veenker     181500       1262
# 2         CollgCr     223500       1786
# 3         Crawfor     140000       1717
# 4         NoRidge     250000       2198
# ...           ...        ...        ...
# 1455      Gilbert     175000       1647
# 1456       NWAmes     210000       2073
# 1457      Crawfor     266500       2340
# 1458        NAmes     142125       1078
# 1459      Edwards     147500       1256
#
# [1460 rows x 3 columns]

# %%
df[['Neighborhood','SalePrice','OverallQual']]
# Out:
#      Neighborhood  SalePrice  OverallQual
# 0         CollgCr     208500            7
# 1         Veenker     181500            6
# 2         CollgCr     223500            7
# 3         Crawfor     140000            7
# 4         NoRidge     250000            8
# ...           ...        ...          ...
# 1455      Gilbert     175000            6
# 1456       NWAmes     210000            6
# 1457      Crawfor     266500            7
# 1458        NAmes     142125            5
# 1459      Edwards     147500            5
#
# [1460 rows x 3 columns]

# %%
df[['Neighborhood', 'OverallQual', 'SalePrice']]
# Out:
#      Neighborhood  OverallQual  SalePrice
# 0         CollgCr            7     208500
# 1         Veenker            6     181500
# 2         CollgCr            7     223500
# 3         Crawfor            7     140000
# 4         NoRidge            8     250000
# ...           ...          ...        ...
# 1455      Gilbert            6     175000
# 1456       NWAmes            6     210000
# 1457      Crawfor            7     266500
# 1458        NAmes            5     142125
# 1459      Edwards            5     147500
#
# [1460 rows x 3 columns]

# %%
df[['YearBuilt', 'GarageCars', 'SalePrice']]
# Out:
#       YearBuilt  GarageCars  SalePrice
# 0          2003           2     208500
# 1          1976           2     181500
# 2          2001           2     223500
# 3          1915           3     140000
# 4          2000           3     250000
# ...         ...         ...        ...
# 1455       1999           2     175000
# 1456       1978           2     210000
# 1457       1941           1     266500
# 1458       1950           1     142125
# 1459       1965           1     147500
#
# [1460 rows x 3 columns]

# %%
df[['HouseStyle', 'BldgType', 'SaleCondition']]
# Out:
#      HouseStyle BldgType SaleCondition
# 0        2Story     1Fam        Normal
# 1        1Story     1Fam        Normal
# 2        2Story     1Fam        Normal
# 3        2Story     1Fam       Abnorml
# 4        2Story     1Fam        Normal
# ...         ...      ...           ...
# 1455     2Story     1Fam        Normal
# 1456     1Story     1Fam        Normal
# 1457     2Story     1Fam        Normal
# 1458     1Story     1Fam        Normal
# 1459     1Story     1Fam        Normal
#
# [1460 rows x 3 columns]

# %%
df[['LotArea', 'GrLivArea', 'SalePrice']]
# Out:
#       LotArea  GrLivArea  SalePrice
# 0        8450       1710     208500
# 1        9600       1262     181500
# 2       11250       1786     223500
# 3        9550       1717     140000
# 4       14260       2198     250000
# ...       ...        ...        ...
# 1455     7917       1647     175000
# 1456    13175       2073     210000
# 1457     9042       2340     266500
# 1458     9717       1078     142125
# 1459     9937       1256     147500
#
# [1460 rows x 3 columns]

# %% [markdown]
# ### 3. Row Selection
#
# Q11. Display the first 10 houses from the dataset.
#
# Q12. Display the last 15 houses.
#
# Q13. Show houses from row number 100 to 120.
#
# Q14. Display every alternate house from the first 20 rows.
#
# Q15. Show the details of the 500th house.

# %%
df[0:10]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.tail(15)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# ...

# %%
df[100:121]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 100  101          20       RL          NaN    10603   Pave   NaN      IR1
# 101  102          60       RL         77.0     9206   Pave   NaN      Reg
# 102  103          90       RL         64.0     7018   Pave   NaN      Reg
# 103  104          20       RL         94.0    10402   Pave   NaN      IR1
# 104  105          50       RM          NaN     7758   Pave   NaN      Reg
# 105  106          60       FV         75.0     9375   Pave   NaN      Reg
# 106  107          30       RM         60.0    10800   Pave  Grvl      Reg
# 107  108          20       RM         50.0     6000   Pave   NaN      Reg
# 108  109          50       RM         85.0     8500   Pave   NaN      Reg
# 109  110          20       RL        105.0    11751   Pave   NaN      IR1
# 110  111          50       RL         75.0     9525   Pave   NaN      Reg
# 111  112          80       RL          NaN     7750   Pave   NaN      IR1
# ...

# %%
df.iloc[100:121]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 100  101          20       RL          NaN    10603   Pave   NaN      IR1
# 101  102          60       RL         77.0     9206   Pave   NaN      Reg
# 102  103          90       RL         64.0     7018   Pave   NaN      Reg
# 103  104          20       RL         94.0    10402   Pave   NaN      IR1
# 104  105          50       RM          NaN     7758   Pave   NaN      Reg
# 105  106          60       FV         75.0     9375   Pave   NaN      Reg
# 106  107          30       RM         60.0    10800   Pave  Grvl      Reg
# 107  108          20       RM         50.0     6000   Pave   NaN      Reg
# 108  109          50       RM         85.0     8500   Pave   NaN      Reg
# 109  110          20       RL        105.0    11751   Pave   NaN      IR1
# 110  111          50       RL         75.0     9525   Pave   NaN      Reg
# 111  112          80       RL          NaN     7750   Pave   NaN      IR1
# ...

# %%
df.iloc[0:20:2]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 18  19          20       RL         66.0    13695   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ...

# %%
df.iloc[499]
# Out:
# Id                  500
# MSSubClass           20
# MSZoning             RL
# LotFrontage        70.0
# LotArea            7535
#                   ...
# MoSold                6
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        120000
# Name: 499, Length: 81, dtype: object

# %% [markdown]
# ### 4. loc[] Based Questions
#
# Q16. The CEO wants complete information about the house whose index is 50.
#
# Q17. Display only the SalePrice of the house with index 200.
#
# Q18. Show the Neighborhood and SalePrice for houses with index values from 10 to 20.
#
# Q19. Display OverallQual, GrLivArea, and SalePrice for house index 100.
#
# Q20. Show all information for houses between index 300 and 310.

# %%
df.loc[50]
# Out:
# Id                   51
# MSSubClass           60
# MSZoning             RL
# LotFrontage         NaN
# LotArea           13869
#                   ...
# MoSold                7
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        177000
# Name: 50, Length: 81, dtype: object

# %%
df.loc[200,'SalePrice']
# Out:
# np.int64(140000)

# %%
df.loc[200, 'SalePrice']
# Out:
# np.int64(140000)

# %%
df.loc[0:10,['Neighborhood', 'SalePrice']]
# Out:
#    Neighborhood  SalePrice
# 0       CollgCr     208500
# 1       Veenker     181500
# 2       CollgCr     223500
# 3       Crawfor     140000
# 4       NoRidge     250000
# 5       Mitchel     143000
# 6       Somerst     307000
# 7        NWAmes     200000
# 8       OldTown     129900
# 9       BrkSide     118000
# 10       Sawyer     129500

# %%
df.loc[100, ['OverallQual', 'GrLivArea', 'SalePrice']]
# Out:
# OverallQual         6
# GrLivArea        1610
# SalePrice      205000
# Name: 100, dtype: int64

# %%
df.loc[300:310]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 300  301         190       RL         90.0    15750   Pave   NaN      Reg
# 301  302          60       RL         66.0    16226   Pave   NaN      IR3
# 302  303          20       RL        118.0    13704   Pave   NaN      IR1
# 303  304          20       RL         70.0     9800   Pave   NaN      Reg
# 304  305          75       RM         87.0    18386   Pave   NaN      Reg
# 305  306          20       RL         80.0    10386   Pave   NaN      Reg
# 306  307          60       RL        116.0    13474   Pave   NaN      Reg
# 307  308          50       RM          NaN     7920   Pave  Grvl      IR1
# 308  309          30       RL          NaN    12342   Pave   NaN      IR1
# 309  310          20       RL         90.0    12378   Pave   NaN      IR1
# 310  311          60       RL          NaN     7685   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# ### iloc[] Based Questions
#
# Q21. Display the complete record of the first house using iloc.
#
# Q22. Show the first five houses and only the first four columns.
#
# Q23. Display rows 50 to 60 and columns 2 to 8.
#
# Q24. Show the SalePrice column using its positional index.
#
# Q25. Display the last 10 rows and the last 5 columns.

# %%
df.iloc[0]
# Out:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage        65.0
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object

# %%
df.iloc[0:5,0:4]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage
# 0   1          60       RL         65.0
# 1   2          20       RL         80.0
# 2   3          60       RL         68.0
# 3   4          70       RL         60.0
# 4   5          60       RL         84.0

# %%
df.iloc[50:61,2:9]
# Out:
#    MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour
# 50       RL          NaN    13869   Pave   NaN      IR2         Lvl
# 51       RM         52.0     6240   Pave   NaN      Reg         Lvl
# 52       RM        110.0     8472   Grvl   NaN      IR2         Bnk
# 53       RL         68.0    50271   Pave   NaN      IR1         Low
# 54       RL         60.0     7134   Pave   NaN      Reg         Bnk
# 55       RL        100.0    10175   Pave   NaN      IR1         Lvl
# 56       FV         24.0     2645   Pave  Pave      Reg         Lvl
# 57       RL         89.0    11645   Pave   NaN      IR1         Lvl
# 58       RL         66.0    13682   Pave   NaN      IR2         HLS
# 59       RL         60.0     7200   Pave   NaN      Reg         Bnk
# 60       RL         63.0    13072   Pave   NaN      Reg         Lvl

# %%
df.iloc[:, 80]
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df.iloc[-10:, -5:]
# Out:
#       MoSold  YrSold SaleType SaleCondition  SalePrice
# 1450       9    2009       WD        Normal     136000
# 1451       5    2009      New       Partial     287090
# 1452       5    2006       WD        Normal     145000
# 1453       7    2006       WD       Abnorml      84500
# 1454      10    2009       WD        Normal     185000
# 1455       8    2007       WD        Normal     175000
# 1456       2    2010       WD        Normal     210000
# 1457       5    2010       WD        Normal     266500
# 1458       4    2010       WD        Normal     142125
# 1459       6    2008       WD        Normal     147500
